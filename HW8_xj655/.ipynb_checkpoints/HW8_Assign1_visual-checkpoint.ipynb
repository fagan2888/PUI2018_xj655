# %% [markdown]
# # HW8_Assign1_xj655
# ### I'm trying plot the subway station entrance  and housing rent on NYC map by PUMA.  Hope to figure out whether the denser subway stations are in one place, the higher the housing rent cost is.

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from geopandas import GeoDataFrame
from matplotlib import pyplot as plt
from fiona.crs import from_epsg
import shapely
import os
import io
import glob
import requests
import json
import pysal
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib
# %matplotlib inline
# Out:
# /anaconda3/lib/python3.6/site-packages/pysal/__init__.py:65: VisibleDeprecationWarning: PySAL's API will be changed on 2018-12-31. The last release made with this API is version 1.14.4. A preview of the next API version is provided in the `pysal` 2.0 prelease candidate. The API changes and a guide on how to change imports is provided at https://pysal.org/about
#   ), VisibleDeprecationWarning)

# %%
os.environ["PUIDATA"] = "%s/PUIdata"%os.getenv("HOME")
print("PUIdata", os.getenv("PUIDATA"))
# Out:
# PUIdata /Users/xiaojing/PUIdata

# %% [markdown]
# ## 1.Get the PUMA for NYC

# %%
url = 'https://data.cityofnewyork.us/api/geospatial/cwiz-gcty?method=export&format=Shapefile'
urllib.urlretrieve(url, "file.gz")
# Out:
# ('file.gz', <http.client.HTTPMessage at 0x1a1539d828>)

# %%
# !unzip file.gz
# Out:
# Archive:  file.gz
#   inflating: geo_export_571cc344-41f5-46ee-ae53-b43c11a7eaae.dbf
#   inflating: geo_export_571cc344-41f5-46ee-ae53-b43c11a7eaae.shp
#   inflating: geo_export_571cc344-41f5-46ee-ae53-b43c11a7eaae.shx
#   inflating: geo_export_571cc344-41f5-46ee-ae53-b43c11a7eaae.prj

# %%
for file in os.listdir():
    if file.endswith(".shp"):
        os.rename(file, 'puma.shp')
    elif file.endswith(".shx"):
        os.rename(file, 'puma.shx')
    elif file.endswith(".dbf"):
        os.rename(file, 'puma.dbf')
    elif file.endswith(".prj"):
        os.rename(file, 'puma.prj')

# %%
pumashp = gpd.GeoDataFrame.from_file('puma.shp')

# %%
pumashp.head()
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002302
# 2  3703  2.670137e+08  304071.257466
# 3  3704  1.062129e+08   47970.901277
# 4  4015  8.105438e+07   50007.415493
#
#                                             geometry
# 0  POLYGON ((-73.89641133483133 40.90450452082026...
# 1  POLYGON ((-73.8442314689986 40.86942035096838,...
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...
# 4  POLYGON ((-73.95374853778468 40.63858633758547...

# %% [markdown]
# ### 2. Get data for NYC subway station info

# %%
url2 = 'https://data.cityofnewyork.us/api/geospatial/drex-xx56?method=export&format=Shapefile'
urllib.urlretrieve(url2, "station.gz")
# Out:
# ('station.gz', <http.client.HTTPMessage at 0x1a15d6dda0>)

# %%
# !unzip station.gz
# Out:
# Archive:  station.gz
#   inflating: geo_export_b75f124b-ca87-406b-9fd1-e048b248e441.dbf
#   inflating: geo_export_b75f124b-ca87-406b-9fd1-e048b248e441.shp
#   inflating: geo_export_b75f124b-ca87-406b-9fd1-e048b248e441.shx
#   inflating: geo_export_b75f124b-ca87-406b-9fd1-e048b248e441.prj

# %%
stationshp = gpd.GeoDataFrame.from_file('geo_export_b75f124b-ca87-406b-9fd1-e048b248e441.shp')

# %%
stationshp.head()
# Out:
#   line                                     name  objectid  \
# 0  2-5  Birchall Ave & Sagamore St at NW corner    1734.0
# 1  2-5  Birchall Ave & Sagamore St at NE corner    1735.0
# 2  2-5  Morris Park Ave & 180th St at NW corner    1736.0
# 3  2-5  Morris Park Ave & 180th St at NW corner    1737.0
# 4  2-5        Boston Rd & 178th St at SW corner    1738.0
#
#                                  url  \
# 0  http://web.mta.info/nyct/service/
# 1  http://web.mta.info/nyct/service/
# 2  http://web.mta.info/nyct/service/
# 3  http://web.mta.info/nyct/service/
# 4  http://web.mta.info/nyct/service/
#
#                                        geometry
# 0  POINT (-73.86835600032798 40.84916900104506)
# 1  POINT (-73.86821300022677 40.84912800131844)
# 2  POINT (-73.87349900050798 40.84122300105249)
# 3  POINT (-73.87289199978331 40.84145300067447)
# 4  POINT (-73.87962300013866 40.84081500075867)

# %%
stationshp.shape
# Out:
# (1928, 5)

# %%
stationshp = pumashp.merge(stationshp, left_on = 'geometry')

# %% [markdown]
# ## 3. Download the csv data for housing rent cost by PUMA.

# %%
#Dataset for housing rent cost. HD01_VD01 means total housing units. HD02_VD01 means std for the previous column(which will be drop later. 
#HD01_VD02 means the number of unit of which rent is from 0-$100, each bin's range is $100. For example, n*100 to n*100+$100 is the interval for Column HD01_VD(n+2). 
acs = pd.read_csv("ACS_16_1YR_B25104_with_ann.csv").drop(index=0).reset_index(drop=True)
acs['GEO.id2'] = acs['GEO.id2'].astype(int) - 3600000
acs.head(50)
# Out:
#               GEO.id  GEO.id2  \
# 0   7950000US3600100      100
# 1   7950000US3600200      200
# 2   7950000US3600300      300
# 3   7950000US3600401      401
# 4   7950000US3600402      402
# 5   7950000US3600403      403
# 6   7950000US3600500      500
# 7   7950000US3600600      600
# 8   7950000US3600701      701
# 9   7950000US3600702      702
# 10  7950000US3600703      703
# 11  7950000US3600704      704
# 12  7950000US3600800      800
# 13  7950000US3600901      901
# 14  7950000US3600902      902
# 15  7950000US3600903      903
# 16  7950000US3600904      904
# 17  7950000US3600905      905
# 18  7950000US3600906      906
# 19  7950000US3601000     1000
# 20  7950000US3601101     1101
# 21  7950000US3601102     1102
# 22  7950000US3601201     1201
# 23  7950000US3601202     1202
# 24  7950000US3601203     1203
# 25  7950000US3601204     1204
# 26  7950000US3601205     1205
# 27  7950000US3601206     1206
# 28  7950000US3601207     1207
# 29  7950000US3601300     1300
# 30  7950000US3601400     1400
# 31  7950000US3601500     1500
# 32  7950000US3601600     1600
# 33  7950000US3601700     1700
# 34  7950000US3601801     1801
# 35  7950000US3601802     1802
# 36  7950000US3601900     1900
# 37  7950000US3602001     2001
# 38  7950000US3602002     2002
# 39  7950000US3602100     2100
# 40  7950000US3602201     2201
# 41  7950000US3602202     2202
# 42  7950000US3602203     2203
# 43  7950000US3602300     2300
# 44  7950000US3602401     2401
# 45  7950000US3602402     2402
# 46  7950000US3602500     2500
# 47  7950000US3602600     2600
# 48  7950000US3602701     2701
# 49  7950000US3602702     2702
#
#                                     GEO.display-label HD01_VD01 HD02_VD01  \
# 0                  St. Lawrence County PUMA, New York     40479      1519
# 1   Clinton, Franklin, Essex & Hamilton Counties P...     67092      2054
# 2         Warren & Washington Counties PUMA, New York     51614      1736
# 3   Herkimer (North & Central) & Oneida (Outer) Co...     44300      1723
# 4   Oneida County (Central)--Greater Utica & Rome ...     61146      1901
# 5   Otsego, Schoharie, Oneida (South) & Herkimer (...     42081      1597
# 6           Jefferson & Lewis Counties PUMA, New York     50860      1725
# 7                        Oswego County PUMA, New York     44633      1313
# 8   Onondaga County (Central)--Syracuse City PUMA,...     56295      2177
# 9              Onondaga County (North) PUMA, New York     47988      1841
# 10  Onondaga County (Central)--Syracuse City (Oute...     65650      1907
# 11  Cayuga & Onondaga (South) Counties PUMA, New York     44017      1591
# 12             Wayne & Seneca Counties PUMA, New York     50496      1342
# 13                Monroe County (East) PUMA, New York     54567      1733
# 14  Monroe County (Central)--Rochester City (East)...     47005      2677
# 15  Monroe County (Central)--Rochester City (West)...     37435      1958
# 16  Monroe County (Central)--Greece & Gates Towns ...     53507      1610
# 17        Monroe County (North & West) PUMA, New York     39808      1805
# 18               Monroe County (South) PUMA, New York     66902      2667
# 19          Genesee & Orleans Counties PUMA, New York     39793      1150
# 20  Niagara County (Southwest)--Greater Niagara Fa...     44915      1784
# 21       Niagara County (North & East) PUMA, New York     41871      1910
# 22             Erie County (Northwest) PUMA, New York     44657      1804
# 23         Erie County (North Central) PUMA, New York     50286      1940
# 24             Erie County (Northeast) PUMA, New York     46712      1979
# 25               Erie County (Central) PUMA, New York     66143      2145
# 26  Erie County (West Central)--Buffalo City (East...     58418      2358
# 27  Erie County (West Central)--Buffalo City (West...     47721      2253
# 28                 Erie County (South) PUMA, New York     66536      2276
# 29       Livingston & Wyoming Counties PUMA, New York     39642      1060
# 30            Ontario & Yates Counties PUMA, New York     53915      1596
# 31         Madison & Cortland Counties PUMA, New York     42758      1611
# 32        Fulton & Montgomery Counties PUMA, New York     42734      1301
# 33  Schenectady County--Schenectady City PUMA, New...     48720      1926
# 34   Saratoga County (South & Central) PUMA, New York     44377      1656
# 35             Saratoga County (Outer) PUMA, New York     49326      1920
# 36        Rensselaer County--Troy City PUMA, New York     62816      1588
# 37  Albany County (East Central)--Albany City PUMA...     44892      2193
# 38  Albany County (Outside Albany City) PUMA, New ...     80437      2065
# 39          Columbia & Greene Counties PUMA, New York     41558      1707
# 40  Broome County (West Central)--Greater Binghamt...     50253      1752
# 41  Broome (Outer West) & Tioga Counties PUMA, New...     41883      1502
# 42  Chenango, Delaware & Broome (East) Counties PU...     42770      1615
# 43                     Tompkins County PUMA, New York     37683      1516
# 44  Chemung (South) & Steuben (East) Counties--Gre...     41759      1619
# 45  Steuben (North & West), Schuyler & Chemung (No...     37389      1328
# 46     Cattaraugus & Allegany Counties PUMA, New York     49474      1383
# 47                   Chautauqua County PUMA, New York     51705      1835
# 48   Sullivan & Ulster (West) Counties PUMA, New York     36989      1763
# 49                Ulster County (East) PUMA, New York     56340      2044
#
#    HD01_VD02 HD02_VD02 HD01_VD03 HD02_VD03 HD01_VD04    ...    HD01_VD13  \
# 0         85        90      1004       422      4013    ...         1710
# 1        404       230      1500       514      4963    ...         4312
# 2        172       162       668       316      1939    ...         5399
# 3         27        34      1574       507      2595    ...         3163
# 4        166       134       636       289      2871    ...         3461
# 5        163       144      1196       389      2554    ...         3362
# 6        106        92      1222       516      2871    ...         5137
# 7          0       192       533       272      2264    ...         3232
# 8        368       219       940       394      2912    ...         2293
# 9         40        64       397       257      1118    ...         6338
# 10        40        67       414       267      2248    ...         6562
# 11       153       179       720       402      1839    ...         4699
# 12       191       163       749       323      2732    ...         4670
# 13       113       137       382       242       979    ...         7380
# 14        24        39       272       215      2335    ...         1867
# 15        63        76       444       289      1935    ...         1514
# 16         0       192       215       183      1227    ...         5109
# 17        79       135       274       270       864    ...         4913
# 18         0       192       241       211       958    ...         9483
# 19        81       134       494       245      1775    ...         2636
# 20        44        73       523       279      2729    ...         2771
# 21       295       445       751       531      2164    ...         4145
# 22         0       192       367       246      1226    ...         3347
# 23       349       250       274       264      1644    ...         7405
# 24        75       125       658       297      1137    ...         5912
# 25        48        80       789       425      2477    ...         3909
# 26       210       226      2406       573      6403    ...          770
# 27       281       168       992       434      2120    ...         1665
# 28        45        77       608       258      1647    ...         7016
# 29        75        98       540       326      1533    ...         2800
# 30        37        90       328       226      1988    ...         5922
# 31        28        32       735       336      1736    ...         4182
# 32        20        34       445       251      2392    ...         2379
# 33        99       118       370       375      1237    ...         6263
# 34       143       168       446       302      1355    ...         5938
# 35         0       192       616       393      1351    ...         8057
# 36        21        37       641       297      1821    ...         8172
# 37        64        81       344       310      1289    ...         4445
# 38        98       131       557       344      1479    ...        12363
# 39         0       192       505       351      1495    ...         4804
# 40        69        92       671       449      1833    ...         2584
# 41       568       357       739       468      2230    ...         3358
# 42       235       191      1378       509      3266    ...         2660
# 43        94       160       369       267       809    ...         4981
# 44       109       121       581       289      2291    ...         3051
# 45       111       136       808       297      3014    ...         2150
# 46       506       215      1149       356      3970    ...         1832
# 47        51        86      1531       500      2619    ...         2289
# 48         0       192       418       281      1294    ...         3935
# 49         0       192       403       290       812    ...         9245
#
#    HD02_VD13 HD01_VD14 HD02_VD14 HD01_VD15 HD02_VD15 HD01_VD16 HD02_VD16  \
# 0        448       787       307       332       206       461       296
# 1        961      1614       449       527       299       447       235
# 2        931      2226       654       787       378       785       324
# 3        684       984       406       163        91       294       198
# 4        812      2181       783       546       308      1020       457
# 5        599      1338       411       655       295       532       230
# 6       1007      1464       430       570       289       399       231
# 7        799      1367       578       187       149       402       298
# 8        658       597       307       151       185       221       230
# 9       1073      2136       605      1109       437      1209       570
# 10      1128      2889       647      1975       596      1988       534
# 11       891      1166       325       718       253       607       243
# 12       993       911       421       543       269       436       282
# 13      1326      2829       813      2089       604      1627       524
# 14       571       435       240       105       102       166       135
# 15       692       714       398       166       204       210       205
# 16       994      1604       641       421       365       655       337
# 17       937      1616       543       872       414       621       304
# 18      1215      4193       901      2181       557      3476       752
# 19       662       762       330       400       261       264       179
# 20       837      1293       540       426       344       211       221
# 21       818      1248       481      1007       384       979       548
# 22       849      1342       572       267       193       382       287
# 23      1377      1985       697      1433       574       835       397
# 24      1324      2481       634      1485       570      1762       590
# 25       919      1229       512       458       263       155       122
# 26       389       269       195         0       192        99       120
# 27       484      1209       479       647       298       564       274
# 28      1090      2793       775      2318       691      1104       443
# 29       577       809       369       529       310       448       242
# 30       932      2097       613      1755       810       883       399
# 31       879      1460       491       319       214       948       374
# 32       558       265       143       169       140       432       282
# 33      1118      2685       741      1259       428       992       435
# 34      1094      3556       930      2071       768      2879       654
# 35      1376      3419       801      2741       632      2031       627
# 36      1212      4699      1017      2388       720       756       315
# 37       902      1482       503       649       396       487       262
# 38      1288      6961      1059      2754       680      3279       771
# 39       822      2433       653      1181       363       866       260
# 40       635       708       371       306       235       408       258
# 41       784      1410       441       449       225       705       387
# 42       663       602       290       343       188       180        97
# 43       813      1947       641      1021       458      1398       557
# 44       876      1328       417       509       302       434       216
# 45       479       639       250       200       133       211       100
# 46       383       446       189       467       263       165       122
# 47       525       419       205       188       109       259       167
# 48       909      2748       770       709       307       909       429
# 49      1230      5372       935      2669       809      2286       703
#
#    HD01_VD17 HD02_VD17
# 0        906       328
# 1       1593       557
# 2        703       384
# 3       1130       485
# 4       1018       463
# 5        886       359
# 6        982       393
# 7       1117       441
# 8        556       312
# 9        693       428
# 10       891       340
# 11       804       276
# 12       605       268
# 13       307       265
# 14       622       409
# 15       185       181
# 16       993       604
# 17        53        88
# 18       466       265
# 19       853       268
# 20       366       275
# 21       504       277
# 22       179       227
# 23       339       233
# 24       311       235
# 25       486       278
# 26      1366       466
# 27      1150       600
# 28       941       400
# 29       750       276
# 30       671       296
# 31       703       251
# 32      1301       612
# 33       718       648
# 34       465       311
# 35       653       414
# 36       605       365
# 37       242       209
# 38       755       537
# 39      1081       409
# 40       746       384
# 41      1081       542
# 42      1402       444
# 43       879       399
# 44       641       409
# 45      1003       375
# 46       961       305
# 47       734       250
# 48      1494       719
# 49      1062       565
#
# [50 rows x 37 columns]

# %%
#the number for column 100~200 means (the unit in the interval)/ (total unit)
acs_new = acs.rename(columns={'GEO.id2' :'puma','HD01_VD01':'total units'}).iloc[:,1::2]
acs_new['total units'] = acs_new['total units'].astype(int)
for i in range(2,18):
    acs_new.rename(columns={acs_new.columns[i] :'$%d~%d'%((int(i-2)*100),int((i-1)*100))}, inplace=True)
    acs_new[acs_new.columns[i]] = acs_new[acs_new.columns[i]].astype(int)
    acs_new[acs_new.columns[i]] = acs_new[acs_new.columns[i]]/acs_new['total units']
acs_new.head()
# Out:
#    puma  total units    $0~100  $100~200  $200~300  $300~400  $400~500  \
# 0   100        40479  0.002100  0.024803  0.099138  0.087082  0.111539
# 1   200        67092  0.006022  0.022357  0.073973  0.074420  0.090786
# 2   300        51614  0.003332  0.012942  0.037567  0.081335  0.061166
# 3   401        44300  0.000609  0.035530  0.058578  0.084673  0.096366
# 4   402        61146  0.002715  0.010401  0.046953  0.060593  0.094348
#
#    $500~600  $600~700  $700~800  $800~900  $900~1000  $1000~1100  $1100~1200  \
# 0  0.082240  0.095037  0.101509  0.061044   0.056326    0.175523    0.042244
# 1  0.100802  0.107867  0.083244  0.075449   0.066521    0.171973    0.064270
# 2  0.070698  0.078273  0.063975  0.083582   0.064944    0.250378    0.104603
# 3  0.094898  0.105801  0.083070  0.073115   0.050113    0.187810    0.071400
# 4  0.094577  0.104013  0.110539  0.075442   0.066971    0.198917    0.056602
#
#    $1200~1300  $1300~1400  $1400~1500  $1500~1600
# 0    0.019442    0.008202    0.011389    0.022382
# 1    0.024057    0.007855    0.006662    0.023744
# 2    0.043128    0.015248    0.015209    0.013620
# 3    0.022212    0.003679    0.006637    0.025508
# 4    0.035669    0.008929    0.016681    0.016649

# %%
acs_new.shape
# Out:
# (145, 18)

# %%
# I'm going to look for the median rent price located in which interval.
#When find the interval, I use the middle number of the interval as the median rent for that area.
acumu = 0
acs_new['median rent'] = 0
for i in range(144):
    for j in range(2,18):
        if acumu < 0.5:
            acumu+=acs_new.iloc[i,j]
        else:
            acumu = 0
            col = j
            break
    acs_new['median rent'][i] = (col-2)*100+50
acs_new.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
#    puma  total units    $0~100  $100~200  $200~300  $300~400  $400~500  \
# 0   100        40479  0.002100  0.024803  0.099138  0.087082  0.111539
# 1   200        67092  0.006022  0.022357  0.073973  0.074420  0.090786
# 2   300        51614  0.003332  0.012942  0.037567  0.081335  0.061166
# 3   401        44300  0.000609  0.035530  0.058578  0.084673  0.096366
# 4   402        61146  0.002715  0.010401  0.046953  0.060593  0.094348
#
#    $500~600  $600~700  $700~800  $800~900  $900~1000  $1000~1100  $1100~1200  \
# 0  0.082240  0.095037  0.101509  0.061044   0.056326    0.175523    0.042244
# 1  0.100802  0.107867  0.083244  0.075449   0.066521    0.171973    0.064270
# 2  0.070698  0.078273  0.063975  0.083582   0.064944    0.250378    0.104603
# 3  0.094898  0.105801  0.083070  0.073115   0.050113    0.187810    0.071400
# 4  0.094577  0.104013  0.110539  0.075442   0.066971    0.198917    0.056602
#
#    $1200~1300  $1300~1400  $1400~1500  $1500~1600  medium rent  median rent
# 0    0.019442    0.008202    0.011389    0.022382          750          750
# 1    0.024057    0.007855    0.006662    0.023744          850          850
# 2    0.043128    0.015248    0.015209    0.013620         1050         1050
# 3    0.022212    0.003679    0.006637    0.025508          850          850
# 4    0.035669    0.008929    0.016681    0.016649          850          850

# %%
medrent_puma = acs_new[['puma','median rent']]
medrent_puma.head()
# Out:
#    puma  median rent
# 0   100          750
# 1   200          850
# 2   300         1050
# 3   401          850
# 4   402          850

# %%
pumashp.puma = pumashp.puma.astype(int)
rent_puma = gpd.GeoDataFrame(pumashp.merge(medrent_puma,left_on='puma',right_on='puma'))
rent_puma.crs = from_epsg(4436)

rent_puma.head()
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002302
# 2  3703  2.670137e+08  304071.257466
# 3  3704  1.062129e+08   47970.901277
# 4  4015  8.105438e+07   50007.415493
#
#                                             geometry  median rent
# 0  POLYGON ((-73.89641133483133 40.90450452082026...         1150
# 1  POLYGON ((-73.8442314689986 40.86942035096838,...         1150
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...         1150
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...         1150
# 4  POLYGON ((-73.95374853778468 40.63858633758547...         1150

# %%
stationshp.crs=from_epsg(4436)

# %%
fig = plt.figure(figsize=(13,11))
ax = fig.add_subplot(111)
g_plot = rent_puma.plot(column = 'median rent',cmap = 'magma', edgecolor='w', ax=ax,lw=1,k=10,alpha=1.0,legend='median rent price')
stationshp.plot(column='objectid',color='blue',legend='subway entry' ,ax = ax,markersize =2,alpha=0.8)
plt.title('Housing rent median price per PUMA & Subway station distribution',fontsize=16)
plt.legend()
#ccent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, 
#CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, 
#Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, 
#Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, 
#PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, 
#RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, 
#Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, 
#YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, 
#autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, 
#cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, 
#flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, inferno, inferno_r, jet, jet_r, magma, magma_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, 
#tab20c_r, terrain, terrain_r, viridis, viridis_r, winter, winter_
# Out:
# /anaconda3/lib/python3.6/site-packages/geopandas/plotting.py:393: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   "'color'.", UserWarning)
# No handles with labels found to put in legend.

# %% [markdown]
# The graph demonstrates the housing median rent cost by PUMA in NYC. THe darker means lower rent per unit and the ligher yellow means higher rent per unit. It shows that in downtown the denser the stations are ,the higher the cost is. However, when the area is far away from downtown, the price have less correlation with station density.
