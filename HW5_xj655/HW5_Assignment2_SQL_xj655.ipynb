# %% [markdown]
# # HW5-2_xj655 SQL

# %%
try:
    import urllib2 as ulib
except ImportError:
    import urllib3 as ulib

try:
    from StringIO import BytesIO as io
except ImportError:
    from io import BytesIO as io

try:
    from urllib import urlencode as urlencode
except ImportError:
    from urllib.parse import urlencode as urlencode
    
try:
    from urllib import urlopen as urlopen
except ImportError:
    from urllib.request import urlopen as urlopen
    
try:
    from urllib2 import HTTPError as HTTPError
except ImportError:
    from urllib.error import HTTPError as HTTPError

import ast
import pandas as pd

# %%
API_URL = 'https://fb55.carto.com:443/api/v2/sql?q='

def queryCartoDB(query, formatting = 'CSV', source = API_URL):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    
    data = urlencode({'format': formatting, 'q': query}).encode("utf-8")
    try:
        response = urlopen(source, data)
        return response.read()
    except HTTPError as e:
        raise (ValueError('\n'.join(ast.literal_eval(e.readline())['error'])))
        
def get_data(query):
    try:
        return pd.read_csv(io(queryCartoDB(query)), sep = ',')
    except ValueError as v:
        print (str(v))

# %%
query = '''SELECT * FROM fb55.citibike; '''
table = get_data(query)
table.head(5)
# Out:
#    the_geom  start_station_name  the_geom_webmercator  field_1  \
# 0       NaN  E 20 St & Park Ave                   NaN      175
# 1       NaN    W 43 St & 10 Ave                   NaN     1159
# 2       NaN   E 6 St & Avenue B                   NaN     2827
# 3       NaN     E 12 St & 3 Ave                   NaN     4961
# 4       NaN     W 41 St & 8 Ave                   NaN     6156
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.987520          1090  2015-02-01 01:23:00+00
# 1               -73.994618           682  2015-02-01 10:55:00+00
# 2               -73.981854           751  2015-02-01 13:59:00+00
# 3               -73.988900           272  2015-02-01 17:28:00+00
# 4               -73.990026           240  2015-02-01 21:36:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 01:42:00+00               503         107
# 1  2015-02-01 11:07:00+00               515        1088
# ...

# %% [markdown]
# # Task 1 — Familiarize with SQL Clauses

# %%
#Sort data by start_station_id, tripduration. Only checking trips with duration <= 3 hours

query = '''SELECT * FROM fb55.citibike 
        WHERE tripduration <= 3*3600
        ORDER BY start_station_id ASC 
        LIMIT 10'''
table = get_data(query)
table.head(11)
# Out:
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN   W 52 St & 11 Ave                   NaN     3370
# 1       NaN   W 52 St & 11 Ave                   NaN     4024
# 2       NaN   W 52 St & 11 Ave                   NaN     2348
# 3       NaN   W 52 St & 11 Ave                   NaN     2051
# 4       NaN   W 52 St & 11 Ave                   NaN      455
# 5       NaN   W 52 St & 11 Ave                   NaN     1597
# 6       NaN   W 52 St & 11 Ave                   NaN     2208
# 7       NaN   W 52 St & 11 Ave                   NaN      718
# 8       NaN   W 52 St & 11 Ave                   NaN     1299
# 9       NaN   W 52 St & 11 Ave                   NaN     5202
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.993929           569  2015-02-01 14:52:00+00
# 1               -73.993929           387  2015-02-01 15:57:00+00
# 2               -73.993929           301  2015-02-01 13:08:00+00
# ...

# %%
#List all unique start_station_id values
query = '''Select distinct start_station_id from fb55.citibike 
where start_station_id is not null
order by start_station_id
         '''
table = get_data(query)
table.head()
# Out:
#    start_station_id  Unnamed: 1
# 0                72         NaN
# 1                79         NaN
# 2                82         NaN
# 3                83         NaN
# 4               116         NaN

# %%
#Aggregation functions:
#Count the number of trips (aka wc -l in SQL) 
#Find the average/min/max trip duration
query = '''Select count(starttime) as number_of_trip, avg(tripduration), min(tripduration), max(tripduration) from fb55.citibike 
where start_station_id is not null
         '''
table = get_data(query)
table
# Out:
#    number_of_trip         avg  min    max
# 0           46200  675.865823   60  43016

# %% [markdown]
# # Task 2 — Working with date/time

# %% [markdown]
# Selecting trips started on Feb-02-2015 only
#
# Selecting trips started on the weekends
#     What are average trip duration during weekends?
#
# Can we do the same for weekday?

# %%
query = '''Select * From fb55.citibike
Where Extract(YEAR FROM starttime::date)>=2015 AND
Extract(MONTH FROM starttime::date)>=2 AND
Extract(DAY FROM starttime::date)>=2
         '''
table = get_data(query)
table
# Out:
#        the_geom        start_station_name  the_geom_webmercator  field_1  \
# 0           NaN           5 Ave & E 29 St                   NaN     7433
# 1           NaN      Allen St & Hester St                   NaN     7779
# 2           NaN           E 39 St & 3 Ave                   NaN     8327
# 3           NaN          10 Ave & W 28 St                   NaN     9435
# 4           NaN            E 2 St & 2 Ave                   NaN    10472
# 5           NaN           1 Ave & E 44 St                   NaN    10931
# 6           NaN           W 45 St & 6 Ave                   NaN    11361
# 7           NaN           W 18 St & 6 Ave                   NaN    12173
# 8           NaN           E 58 St & 3 Ave                   NaN    12211
# 9           NaN           E 33 St & 5 Ave                   NaN    12560
# 10          NaN           W 31 St & 7 Ave                   NaN    13239
# 11          NaN           5 Ave & E 29 St                   NaN    13365
# ...

# %%
#Selecting trips started on the weekends What are average trip duration during weekends?
query = '''Select * From fb55.citibike
Where extract(dow from starttime)= 0 or
    extract(dow from starttime) = 6
         '''
table = get_data(query)
table
# Out:
#        the_geom        start_station_name  the_geom_webmercator  field_1  \
# 0           NaN        E 20 St & Park Ave                   NaN      175
# 1           NaN          W 43 St & 10 Ave                   NaN     1159
# 2           NaN         E 6 St & Avenue B                   NaN     2827
# 3           NaN           E 12 St & 3 Ave                   NaN     4961
# 4           NaN           W 41 St & 8 Ave                   NaN     6156
# 5           NaN           E 20 St & 2 Ave                   NaN    39894
# 6           NaN        Broadway & W 60 St                   NaN    41512
# 7           NaN         E 6 St & Avenue D                   NaN    41595
# 8           NaN            Great Jones St                   NaN    41806
# 9           NaN           W 13 St & 6 Ave                   NaN    42316
# 10          NaN          W 34 St & 11 Ave                   NaN    42532
# 11          NaN           W 41 St & 8 Ave                   NaN    42915
# ...

# %%
#What are average trip duration during weekends
query = '''Select AVG(tripduration) From fb55.citibike
Where extract(dow from starttime)= 0 or
    extract(dow from starttime) = 6
         '''
table = get_data(query)
table
# Out:
#           avg  Unnamed: 1
# 0  662.942181         NaN

# %%
#Can we do the same for weekday?(another way to contain all the weekday MOnday=1,Tuesday=2,Wednesday=3...Friday=5)
query = '''Select AVG(tripduration) From fb55.citibike
Where extract(dow from starttime) in (1,2,3,4,5)
         '''
#also can add 'not in (0,6)'
table = get_data(query)
table
# Out:
#           avg  Unnamed: 1
# 0  681.052292         NaN

# %%
#solution 2 to do the previous one
query = '''Select AVG(tripduration) From fb55.citibike
Where (extract(dow from starttime) != 0) and
    (extract(dow from starttime) != 6)
         '''
table = get_data(query)
table
# Out:
#           avg  Unnamed: 1
# 0  681.052292         NaN

# %% [markdown]
# # Task 3 — Working with Space

# %% [markdown]
# Showing the list of start station locations
#
# Using GROUP BY

# %%
query = '''Select distinct citibike.start_station_name, avg(citibike.start_station_longitude) as longitude, 
            avg(citibike.start_station_latitude) as latitude 
From fb55.citibike
group by citibike.start_station_name
         '''
table = get_data(query)
table.head(10)
# Out:
#         start_station_name  longitude   latitude
# 0         10 Ave & W 28 St -74.001768  40.750664
# 1         11 Ave & W 27 St -74.005226  40.751396
# 2         11 Ave & W 41 St -73.998842  40.760301
# 3         11 Ave & W 59 St -73.990541  40.771522
# 4         12 Ave & W 40 St -74.002777  40.760875
# 5          1 Ave & E 15 St -73.981656  40.732219
# 6          1 Ave & E 44 St -73.969053  40.750020
# 7          2 Ave & E 31 St -73.977061  40.742909
# 8          2 Ave & E 58 St -73.964785  40.760203
# 9  3 Ave & Schermerhorn St -73.979677  40.686832

# %%
#Showing the number of trips started per station
query = '''Select start_station_name, count(tripduration) From fb55.citibike
group by start_station_name
         '''
table = get_data(query)
table.head(10)
# Out:
#               start_station_name  count
# 0           E 30 St & Park Ave S    227
# 1        Pearl St & Anchorage Pl     54
# 2                W 56 St & 6 Ave    164
# 3                 West Thames St    107
# 4        Bank St & Washington St    125
# 5                8 Ave & W 52 St    133
# 6             E 11 St & Broadway    115
# 7       DeKalb Ave & Skillman St     10
# 8  Atlantic Ave & Fort Greene Pl     36
# 9              Avenue D & E 8 St     38

# %%
#... but only for stations within 500m of Time Square!
#The coordinates of Time Square is (40.7577,-73.9857)
query = '''Select start_station_name, count(tripduration) as number_of_trips,
            start_station_longitude, start_station_latitude
FROM fb55.citibike
WHERE st_dwithin(CDB_LatLng(start_station_latitude,
                            start_station_longitude)::geography,
                CDB_LatLng(40.7577,-73.9857)::geography, 
                500)
GROUP by start_station_name, start_station_longitude,start_station_latitude
         '''
table = get_data(query)
table.head(10)
# Out:
#    start_station_name  number_of_trips  start_station_longitude  \
# 0  Broadway & W 41 St              251               -73.986580
# 1  Broadway & W 49 St              213               -73.984427
# 2     W 41 St & 8 Ave              507               -73.990026
# 3     W 42 St & 8 Ave              221               -73.990985
# 4     W 43 St & 6 Ave              112               -73.983169
# 5     W 45 St & 6 Ave              141               -73.982912
# 6     W 45 St & 8 Ave              141               -73.988597
#
#    start_station_latitude
# 0               40.755136
# 1               40.760647
# 2               40.756405
# 3               40.757570
# 4               40.755273
# 5               40.756800
# 6               40.759291

# %% [markdown]
# # Task 4 — Putting it all together

# %%
#Find the station that had the longest average trip duration during weekends and within 500m of TimeSquare!
query = '''SELECT start_station_name, count(tripduration) as number_of_trips,
             avg(tripduration) AS avg_duration
From fb55.citibike

WHERE st_dwithin(CDB_LatLng(start_station_latitude,
                            start_station_longitude)::geography,
                CDB_LatLng(40.7577,-73.9857)::geography, 
                500)
OR
(EXTRACT(dow from starttime)= 0 or
    extract(dow from starttime) = 6)
    
GROUP by start_station_name
ORDER by avg_duration DESC
LIMIT 1
         '''
table = get_data(query)
table.head(10)
# Out:
#   start_station_name  number_of_trips  avg_duration
# 0    W 33 St & 7 Ave               48      1524.375

# %%
#Extra: create lines for trips started from stations within 500m of Times Squares and lasted less than 2 hours. 
#The number of trips per each pair of stations are output as attributes of these lines.
query = '''SELECT start_station_name, end_station_name, count(tripduration) as number_of_trips, tripduration
From fb55.citibike

WHERE st_dwithin(CDB_LatLng(start_station_latitude,
                            start_station_longitude)::geography,
                CDB_LatLng(40.7577,-73.9857)::geography, 
                500)
AND
(tripduration < 2*3600)
    
GROUP by start_station_name,end_station_name, tripduration
ORDER by tripduration DESC
         '''
table = get_data(query)
table
# Out:
#       start_station_name                   end_station_name  number_of_trips  \
# 0        W 45 St & 8 Ave              E 48 St & Madison Ave                1
# 1        W 45 St & 8 Ave                    W 45 St & 8 Ave                1
# 2        W 42 St & 8 Ave                 Broadway & W 58 St                1
# 3        W 45 St & 6 Ave            E 37 St & Lexington Ave                1
# 4        W 42 St & 8 Ave        Cadman Plaza E & Tillary St                1
# 5        W 45 St & 8 Ave                   W 46 St & 11 Ave                1
# 6        W 45 St & 6 Ave           E 43 St & Vanderbilt Ave                1
# 7        W 42 St & 8 Ave                    W 21 St & 6 Ave                1
# 8        W 43 St & 6 Ave  Grand Army Plaza & Central Park S                1
# 9     Broadway & W 49 St                 Broadway & W 51 St                1
# 10       W 42 St & 8 Ave          Bond St & Schermerhorn St                1
# ...

# %% [markdown]
# # EXTRA CREDIT: I set the environment at the beginning
